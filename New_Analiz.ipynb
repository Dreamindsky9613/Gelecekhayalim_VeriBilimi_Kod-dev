# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data=pd.read_excel("Adidas US Sales Datasets.xlsx")
data
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# 0           NaN            NaN         NaN                      NaN
# 1           NaN            NaN         NaN                      NaN
# 2           NaN            NaN         NaN                      NaN
# 3        Region          State        City                  Product
# 4     Northeast       New York    New York    Men's Street Footwear
# ...         ...            ...         ...                      ...
# 9647  Northeast  New Hampshire  Manchester            Men's Apparel
# 9648  Northeast  New Hampshire  Manchester          Women's Apparel
# 9649  Northeast  New Hampshire  Manchester    Men's Street Footwear
# 9650  Northeast  New Hampshire  Manchester  Men's Athletic Footwear
# 9651  Northeast  New Hampshire  Manchester  Women's Street Footwear
#
#           Unnamed: 8  Unnamed: 9  Unnamed: 10       Unnamed: 11  \
# 0                NaN         NaN          NaN               NaN
# 1                NaN         NaN          NaN               NaN
# 2                NaN         NaN          NaN               NaN
# 3     Price per Unit  Units Sold  Total Sales  Operating Profit
# 4                 50        1200       600000            300000
# ...              ...         ...          ...               ...
# 9647              50          64         3200             896.0
# 9648              41         105         4305            1377.6
# 9649              41         184         7544           2791.28
# 9650              42          70         2940            1234.8
# 9651              29          83         2407            649.89
#
#            Unnamed: 12   Unnamed: 13
# 0                  NaN           NaN
# 1                  NaN           NaN
# 2                  NaN           NaN
# 3     Operating Margin  Sales Method
# 4                  0.5      In-store
# ...                ...           ...
# 9647              0.28        Outlet
# 9648              0.32        Outlet
# 9649              0.37        Outlet
# 9650              0.42        Outlet
# 9651              0.27        Outlet
#
# [9652 rows x 14 columns]

# %%
data.head()
# Out:
#    Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0         NaN          NaN  Adidas Sales Database                  NaN
# 1         NaN          NaN                    NaN                  NaN
# 2         NaN          NaN                    NaN                  NaN
# 3         NaN     Retailer            Retailer ID         Invoice Date
# 4         NaN  Foot Locker                1185732  2020-01-01 00:00:00
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6             Unnamed: 7      Unnamed: 8  \
# 0        NaN        NaN        NaN                    NaN             NaN
# 1        NaN        NaN        NaN                    NaN             NaN
# 2        NaN        NaN        NaN                    NaN             NaN
# 3     Region      State       City                Product  Price per Unit
# 4  Northeast   New York   New York  Men's Street Footwear              50
#
#    Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 0         NaN          NaN               NaN               NaN           NaN
# 1         NaN          NaN               NaN               NaN           NaN
# 2         NaN          NaN               NaN               NaN           NaN
# 3  Units Sold  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4        1200       600000            300000               0.5      In-store

# %%
data.tail(5)
# Out:
#       Unnamed: 0   Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 9647         NaN  Foot Locker    1185732  2021-01-24 00:00:00  Northeast
# 9648         NaN  Foot Locker    1185732  2021-01-24 00:00:00  Northeast
# 9649         NaN  Foot Locker    1185732  2021-02-22 00:00:00  Northeast
# 9650         NaN  Foot Locker    1185732  2021-02-22 00:00:00  Northeast
# 9651         NaN  Foot Locker    1185732  2021-02-22 00:00:00  Northeast
#
#          Unnamed: 5  Unnamed: 6               Unnamed: 7 Unnamed: 8  \
# 9647  New Hampshire  Manchester            Men's Apparel         50
# 9648  New Hampshire  Manchester          Women's Apparel         41
# 9649  New Hampshire  Manchester    Men's Street Footwear         41
# 9650  New Hampshire  Manchester  Men's Athletic Footwear         42
# 9651  New Hampshire  Manchester  Women's Street Footwear         29
#
#      Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 9647         64        3200       896.0        0.28      Outlet
# 9648        105        4305      1377.6        0.32      Outlet
# 9649        184        7544     2791.28        0.37      Outlet
# 9650         70        2940      1234.8        0.42      Outlet
# 9651         83        2407      649.89        0.27      Outlet

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9652 entries, 0 to 9651
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   9649 non-null   object
#  2   Unnamed: 2   9650 non-null   object
#  3   Unnamed: 3   9649 non-null   object
#  4   Unnamed: 4   9649 non-null   object
#  5   Unnamed: 5   9649 non-null   object
#  6   Unnamed: 6   9649 non-null   object
#  7   Unnamed: 7   9649 non-null   object
#  8   Unnamed: 8   9649 non-null   object
#  9   Unnamed: 9   9649 non-null   object
#  10  Unnamed: 10  9649 non-null   object
#  11  Unnamed: 11  9649 non-null   object
#  12  Unnamed: 12  9649 non-null   object
#  13  Unnamed: 13  9649 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 1.0+ MB

# %%
data.drop("Unnamed: 0", axis=1)
# Out:
#        Unnamed: 1             Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0             NaN  Adidas Sales Database                  NaN        NaN
# 1             NaN                    NaN                  NaN        NaN
# 2             NaN                    NaN                  NaN        NaN
# 3        Retailer            Retailer ID         Invoice Date     Region
# 4     Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# ...           ...                    ...                  ...        ...
# 9647  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9648  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9649  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9650  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9651  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
#
#          Unnamed: 5  Unnamed: 6               Unnamed: 7      Unnamed: 8  \
# 0               NaN         NaN                      NaN             NaN
# 1               NaN         NaN                      NaN             NaN
# 2               NaN         NaN                      NaN             NaN
# 3             State        City                  Product  Price per Unit
# 4          New York    New York    Men's Street Footwear              50
# ...             ...         ...                      ...             ...
# 9647  New Hampshire  Manchester            Men's Apparel              50
# 9648  New Hampshire  Manchester          Women's Apparel              41
# 9649  New Hampshire  Manchester    Men's Street Footwear              41
# 9650  New Hampshire  Manchester  Men's Athletic Footwear              42
# 9651  New Hampshire  Manchester  Women's Street Footwear              29
#
#       Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12  \
# 0            NaN          NaN               NaN               NaN
# 1            NaN          NaN               NaN               NaN
# 2            NaN          NaN               NaN               NaN
# 3     Units Sold  Total Sales  Operating Profit  Operating Margin
# 4           1200       600000            300000               0.5
# ...          ...          ...               ...               ...
# 9647          64         3200             896.0              0.28
# 9648         105         4305            1377.6              0.32
# 9649         184         7544           2791.28              0.37
# 9650          70         2940            1234.8              0.42
# 9651          83         2407            649.89              0.27
#
#        Unnamed: 13
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Sales Method
# 4         In-store
# ...            ...
# 9647        Outlet
# 9648        Outlet
# 9649        Outlet
# 9650        Outlet
# 9651        Outlet
#
# [9652 rows x 13 columns]

# %%
df=data.drop("Unnamed: 0",axis=1)
df
# Out:
#        Unnamed: 1             Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0             NaN  Adidas Sales Database                  NaN        NaN
# 1             NaN                    NaN                  NaN        NaN
# 2             NaN                    NaN                  NaN        NaN
# 3        Retailer            Retailer ID         Invoice Date     Region
# 4     Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# ...           ...                    ...                  ...        ...
# 9647  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9648  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9649  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9650  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9651  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
#
#          Unnamed: 5  Unnamed: 6               Unnamed: 7      Unnamed: 8  \
# 0               NaN         NaN                      NaN             NaN
# 1               NaN         NaN                      NaN             NaN
# 2               NaN         NaN                      NaN             NaN
# 3             State        City                  Product  Price per Unit
# 4          New York    New York    Men's Street Footwear              50
# ...             ...         ...                      ...             ...
# 9647  New Hampshire  Manchester            Men's Apparel              50
# 9648  New Hampshire  Manchester          Women's Apparel              41
# 9649  New Hampshire  Manchester    Men's Street Footwear              41
# 9650  New Hampshire  Manchester  Men's Athletic Footwear              42
# 9651  New Hampshire  Manchester  Women's Street Footwear              29
#
#       Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12  \
# 0            NaN          NaN               NaN               NaN
# 1            NaN          NaN               NaN               NaN
# 2            NaN          NaN               NaN               NaN
# 3     Units Sold  Total Sales  Operating Profit  Operating Margin
# 4           1200       600000            300000               0.5
# ...          ...          ...               ...               ...
# 9647          64         3200             896.0              0.28
# 9648         105         4305            1377.6              0.32
# 9649         184         7544           2791.28              0.37
# 9650          70         2940            1234.8              0.42
# 9651          83         2407            649.89              0.27
#
#        Unnamed: 13
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Sales Method
# 4         In-store
# ...            ...
# 9647        Outlet
# 9648        Outlet
# 9649        Outlet
# 9650        Outlet
# 9651        Outlet
#
# [9652 rows x 13 columns]

# %%
df.head(10)
# Out:
#     Unnamed: 1             Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0          NaN  Adidas Sales Database                  NaN        NaN
# 1          NaN                    NaN                  NaN        NaN
# 2          NaN                    NaN                  NaN        NaN
# 3     Retailer            Retailer ID         Invoice Date     Region
# 4  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# 5  Foot Locker                1185732  2020-01-02 00:00:00  Northeast
# 6  Foot Locker                1185732  2020-01-03 00:00:00  Northeast
# 7  Foot Locker                1185732  2020-01-04 00:00:00  Northeast
# 8  Foot Locker                1185732  2020-01-05 00:00:00  Northeast
# 9  Foot Locker                1185732  2020-01-06 00:00:00  Northeast
#
#   Unnamed: 5 Unnamed: 6                 Unnamed: 7      Unnamed: 8  \
# 0        NaN        NaN                        NaN             NaN
# 1        NaN        NaN                        NaN             NaN
# 2        NaN        NaN                        NaN             NaN
# 3      State       City                    Product  Price per Unit
# 4   New York   New York      Men's Street Footwear              50
# 5   New York   New York    Men's Athletic Footwear              50
# 6   New York   New York    Women's Street Footwear              40
# 7   New York   New York  Women's Athletic Footwear              45
# 8   New York   New York              Men's Apparel              60
# 9   New York   New York            Women's Apparel              50
#
#    Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 0         NaN          NaN               NaN               NaN           NaN
# 1         NaN          NaN               NaN               NaN           NaN
# 2         NaN          NaN               NaN               NaN           NaN
# 3  Units Sold  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4        1200       600000            300000               0.5      In-store
# 5        1000       500000            150000               0.3      In-store
# 6        1000       400000            140000              0.35      In-store
# 7         850       382500            133875              0.35      In-store
# 8         900       540000            162000               0.3      In-store
# 9        1000       500000            125000              0.25      In-store

# %%
df= df.rename(columns={'Unnamed: 1': 'Retailer','Unnamed: 2': 'Retailer ID', 'Unnamed: 3':'Invoice Date','Unnamed: 4':'Region','Unnamed: 5':'State',
       'Unnamed: 6':'City','Unnamed: 7':'Product','Unnamed: 8':'Price per unit','Unnamed: 9':'Units sold','Unnamed: 10':'Total Sales',
       'Unnamed: 11':'Operating Profit','Unnamed: 12':'Operating Margin','Unnamed: 13':'Sales method'})

# %%
df
# Out:
#          Retailer            Retailer ID         Invoice Date     Region  \
# 0             NaN  Adidas Sales Database                  NaN        NaN
# 1             NaN                    NaN                  NaN        NaN
# 2             NaN                    NaN                  NaN        NaN
# 3        Retailer            Retailer ID         Invoice Date     Region
# 4     Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# ...           ...                    ...                  ...        ...
# 9647  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9648  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9649  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9650  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9651  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
#
#               State        City                  Product  Price per unit  \
# 0               NaN         NaN                      NaN             NaN
# 1               NaN         NaN                      NaN             NaN
# 2               NaN         NaN                      NaN             NaN
# 3             State        City                  Product  Price per Unit
# 4          New York    New York    Men's Street Footwear              50
# ...             ...         ...                      ...             ...
# 9647  New Hampshire  Manchester            Men's Apparel              50
# 9648  New Hampshire  Manchester          Women's Apparel              41
# 9649  New Hampshire  Manchester    Men's Street Footwear              41
# 9650  New Hampshire  Manchester  Men's Athletic Footwear              42
# 9651  New Hampshire  Manchester  Women's Street Footwear              29
#
#       Units sold  Total Sales  Operating Profit  Operating Margin  \
# 0            NaN          NaN               NaN               NaN
# 1            NaN          NaN               NaN               NaN
# 2            NaN          NaN               NaN               NaN
# 3     Units Sold  Total Sales  Operating Profit  Operating Margin
# 4           1200       600000            300000               0.5
# ...          ...          ...               ...               ...
# 9647          64         3200             896.0              0.28
# 9648         105         4305            1377.6              0.32
# 9649         184         7544           2791.28              0.37
# 9650          70         2940            1234.8              0.42
# 9651          83         2407            649.89              0.27
#
#       Sales method
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Sales Method
# 4         In-store
# ...            ...
# 9647        Outlet
# 9648        Outlet
# 9649        Outlet
# 9650        Outlet
# 9651        Outlet
#
# [9652 rows x 13 columns]

# %%
df.head()
# Out:
#       Retailer            Retailer ID         Invoice Date     Region  \
# 0          NaN  Adidas Sales Database                  NaN        NaN
# 1          NaN                    NaN                  NaN        NaN
# 2          NaN                    NaN                  NaN        NaN
# 3     Retailer            Retailer ID         Invoice Date     Region
# 4  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
#
#       State      City                Product  Price per unit  Units sold  \
# 0       NaN       NaN                    NaN             NaN         NaN
# 1       NaN       NaN                    NaN             NaN         NaN
# 2       NaN       NaN                    NaN             NaN         NaN
# 3     State      City                Product  Price per Unit  Units Sold
# 4  New York  New York  Men's Street Footwear              50        1200
#
#    Total Sales  Operating Profit  Operating Margin  Sales method
# 0          NaN               NaN               NaN           NaN
# 1          NaN               NaN               NaN           NaN
# 2          NaN               NaN               NaN           NaN
# 3  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4       600000            300000               0.5      In-store

# %%
df.tail(5)
# Out:
#          Retailer Retailer ID         Invoice Date     Region          State  \
# 9647  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
#             City                  Product Price per unit Units sold  \
# 9647  Manchester            Men's Apparel             50         64
# 9648  Manchester          Women's Apparel             41        105
# 9649  Manchester    Men's Street Footwear             41        184
# 9650  Manchester  Men's Athletic Footwear             42         70
# 9651  Manchester  Women's Street Footwear             29         83
#
#      Total Sales Operating Profit Operating Margin Sales method
# 9647        3200            896.0             0.28       Outlet
# 9648        4305           1377.6             0.32       Outlet
# 9649        7544          2791.28             0.37       Outlet
# 9650        2940           1234.8             0.42       Outlet
# 9651        2407           649.89             0.27       Outlet

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per unit', 'Units sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales method'],
#       dtype='object')

# %%
columns=list(df.columns)

# %%
columns=list(df.columns)
for i in range(len(columns)):
    df= df.rename(columns={columns[i]:df.iloc[3,i]})

# %%
df.isnull().sum()
# Out:
# Retailer            3
# Retailer ID         2
# Invoice Date        3
# Region              3
# State               3
# City                3
# Product             3
# Price per Unit      3
# Units Sold          3
# Total Sales         3
# Operating Profit    3
# Operating Margin    3
# Sales Method        3
# dtype: int64

# %%
df.isnull().any()
# Out:
# Retailer            True
# Retailer ID         True
# Invoice Date        True
# Region              True
# State               True
# City                True
# Product             True
# Price per Unit      True
# Units Sold          True
# Total Sales         True
# Operating Profit    True
# Operating Margin    True
# Sales Method        True
# dtype: bool

# %%
df= df.iloc[4:]
df
# Out:
#          Retailer Retailer ID         Invoice Date     Region          State  \
# 4     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 8     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9647  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
#             City                    Product Price per Unit Units Sold  \
# 4       New York      Men's Street Footwear             50       1200
# 5       New York    Men's Athletic Footwear             50       1000
# 6       New York    Women's Street Footwear             40       1000
# 7       New York  Women's Athletic Footwear             45        850
# 8       New York              Men's Apparel             60        900
# ...          ...                        ...            ...        ...
# 9647  Manchester              Men's Apparel             50         64
# 9648  Manchester            Women's Apparel             41        105
# 9649  Manchester      Men's Street Footwear             41        184
# 9650  Manchester    Men's Athletic Footwear             42         70
# 9651  Manchester    Women's Street Footwear             29         83
#
#      Total Sales Operating Profit Operating Margin Sales Method
# 4         600000           300000              0.5     In-store
# 5         500000           150000              0.3     In-store
# 6         400000           140000             0.35     In-store
# 7         382500           133875             0.35     In-store
# 8         540000           162000              0.3     In-store
# ...          ...              ...              ...          ...
# 9647        3200            896.0             0.28       Outlet
# 9648        4305           1377.6             0.32       Outlet
# 9649        7544          2791.28             0.37       Outlet
# 9650        2940           1234.8             0.42       Outlet
# 9651        2407           649.89             0.27       Outlet
#
# [9648 rows x 13 columns]

# %%
df=df.reset_index(drop=True)
df
# Out:
#          Retailer Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 1     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 2     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 3     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 4     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
#             City                    Product Price per Unit Units Sold  \
# 0       New York      Men's Street Footwear             50       1200
# 1       New York    Men's Athletic Footwear             50       1000
# 2       New York    Women's Street Footwear             40       1000
# 3       New York  Women's Athletic Footwear             45        850
# 4       New York              Men's Apparel             60        900
# ...          ...                        ...            ...        ...
# 9643  Manchester              Men's Apparel             50         64
# 9644  Manchester            Women's Apparel             41        105
# 9645  Manchester      Men's Street Footwear             41        184
# 9646  Manchester    Men's Athletic Footwear             42         70
# 9647  Manchester    Women's Street Footwear             29         83
#
#      Total Sales Operating Profit Operating Margin Sales Method
# 0         600000           300000              0.5     In-store
# 1         500000           150000              0.3     In-store
# 2         400000           140000             0.35     In-store
# 3         382500           133875             0.35     In-store
# 4         540000           162000              0.3     In-store
# ...          ...              ...              ...          ...
# 9643        3200            896.0             0.28       Outlet
# 9644        4305           1377.6             0.32       Outlet
# 9645        7544          2791.28             0.37       Outlet
# 9646        2940           1234.8             0.42       Outlet
# 9647        2407           649.89             0.27       Outlet
#
# [9648 rows x 13 columns]

# %%
df.tail()
# Out:
#          Retailer Retailer ID         Invoice Date     Region          State  \
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
#             City                  Product Price per Unit Units Sold  \
# 9643  Manchester            Men's Apparel             50         64
# 9644  Manchester          Women's Apparel             41        105
# 9645  Manchester    Men's Street Footwear             41        184
# 9646  Manchester  Men's Athletic Footwear             42         70
# 9647  Manchester  Women's Street Footwear             29         83
#
#      Total Sales Operating Profit Operating Margin Sales Method
# 9643        3200            896.0             0.28       Outlet
# 9644        4305           1377.6             0.32       Outlet
# 9645        7544          2791.28             0.37       Outlet
# 9646        2940           1234.8             0.42       Outlet
# 9647        2407           649.89             0.27       Outlet

# %%
df['Price per Unit'].unique()
# Out:
# array([50, 40, 45, 60, 55.00000000000001, 65, 70, 25, 35, 30, 80, 75,
#        60.00000000000001, 54.99999999999999, 45.00000000000001,
#        64.99999999999999, 20, 30.000000000000004, 24.999999999999996,
#        65.00000000000001, 75.00000000000001, 49.99999999999999,
#        85.00000000000001, 70.00000000000001, 80.00000000000001, 100,
#        75.00000000000003, 90.00000000000001, 95.00000000000001,
#        50.000000000000014, 44.99999999999999, 40.00000000000001,
#        49.999999999999986, 59.999999999999986, 25.000000000000007,
#        19.999999999999996, 14.999999999999996, 35.00000000000001,
#        54.999999999999986, 20.000000000000007, 9.999999999999996,
#        20.000000000000004, 85, 95, 110.00000000000001, 90, 105,
#        55.000000000000014, 29.999999999999993, 40.000000000000014,
#        45.000000000000014, 30.00000000000001, 15.000000000000002,
#        39.99999999999999, 15.000000000000007, 25.00000000000001,
#        10.000000000000002, 34.99999999999999, 44.999999999999986,
#        80.00000000000003, 90.00000000000003, 24.999999999999993,
#        60.00000000000002, 35.000000000000014, 65.00000000000003,
#        20.00000000000001, 30.000000000000014, 15.000000000000014,
#        25.000000000000018, 10.000000000000004, 47, 36, 41, 55, 46, 44, 58,
#        48, 39, 43, 59, 56, 49, 54, 64, 53, 61, 62, 68, 52, 66, 51, 24, 34,
#        33, 23, 32, 38, 29, 37, 27, 42, 72, 63, 69, 76, 67, 57, 28, 18, 19,
#        71, 78, 73, 74, 83, 82, 98, 77, 88, 86, 14, 9, 15, 97, 81, 79, 96,
#        84, 89, 103, 101, 87, 10, 92, 31, 26, 21, 13, 22, 17, 12, 16, 11,
#        7, 8], dtype=object)

# %%
df['Price per Unit'].mean()
# Out:
# np.float64(45.21662520729685)

# %%
df['Units Sold'].mean()
# Out:
# np.float64(256.9300373134328)

# %%
df['Total Sales'].mean()
# Out:
# np.float64(93273.4375)

# %%
df['Operating Profit'].mean()
# Out:
# np.float64(34425.24476057202)

# %%
df["Retailer"].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
df["City"].unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester'], dtype=object)

# %%
df.groupby("Retailer")[["Operating Profit"]].mean().reset_index()
# Out:
#         Retailer Operating Profit
# 0         Amazon      30367.23215
# 1    Foot Locker     30611.348051
# 2         Kohl's     35739.080175
# 3  Sports Direct     36581.178622
# 4        Walmart     41185.387556
# 5      West Gear     36085.877498

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
retailer_region= df.groupby(["Retailer","Region"])[["Units Sold"]].sum().reset_index()
retailer_region
# Out:
#          Retailer     Region Units Sold
# 0          Amazon    Midwest      44925
# 1          Amazon  Northeast      95020
# 2          Amazon      South       1674
# 3          Amazon  Southeast      29622
# 4          Amazon       West      26749
# 5     Foot Locker    Midwest     141281
# 6     Foot Locker  Northeast     179087
# 7     Foot Locker      South      34786
# 8     Foot Locker  Southeast     150781
# 9     Foot Locker       West      98434
# 10         Kohl's    Midwest      62393
# 11         Kohl's  Northeast      37145
# 12         Kohl's      South      12778
# 13         Kohl's       West     175059
# 14  Sports Direct    Midwest      74415
# 15  Sports Direct  Northeast      74310
# 16  Sports Direct      South     231695
# 17  Sports Direct  Southeast     143599
# 18  Sports Direct       West      33621
# 19        Walmart  Northeast      34726
# 20        Walmart      South     117113
# 21        Walmart  Southeast      42013
# 22        Walmart       West      12373
# 23      West Gear    Midwest      68323
# 24      West Gear  Northeast      80991
# 25      West Gear      South      94214
# 26      West Gear  Southeast      40985
# 27      West Gear       West     340749

# %%
plt.figure(figsize=(12,6))
plt.title("Adidas US Sales Datasets")
plt.xlabel=("Retailer")
plt.ylabel=("Units Sold")
sns.barplot(x="Retailer",y="Units Sold",hue="Region",data=retailer_region)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# 0           300000              0.5     In-store
# 1           150000              0.3     In-store
# 2           140000             0.35     In-store
# 3           133875             0.35     In-store
# 4           162000              0.3     In-store

# %%
product_sales=df.groupby(["Product","Region"])[["Units Sold"]].mean().reset_index()
product_sales
# Out:
#                       Product     Region  Units Sold
# 0               Men's Apparel    Midwest  145.205128
# 1               Men's Apparel  Northeast  156.643939
# 2               Men's Apparel      South  210.559028
# 3               Men's Apparel  Southeast  266.593137
# 4               Men's Apparel       West  207.689655
# 5     Men's Athletic Footwear    Midwest  208.717949
# 6     Men's Athletic Footwear  Northeast  205.742424
# 7     Men's Athletic Footwear      South  312.774306
# 8     Men's Athletic Footwear  Southeast  348.671569
# 9     Men's Athletic Footwear       West  311.521951
# 10      Men's Street Footwear    Midwest   352.11859
# 11      Men's Street Footwear  Northeast  339.020202
# 12      Men's Street Footwear      South  369.947917
# 13      Men's Street Footwear  Southeast  450.328431
# 14      Men's Street Footwear       West  367.792683
# 15            Women's Apparel    Midwest  222.548077
# 16            Women's Apparel  Northeast  227.393939
# 17            Women's Apparel      South     308.125
# 18            Women's Apparel  Southeast  337.446078
# 19            Women's Apparel       West  286.188725
# 20  Women's Athletic Footwear    Midwest  143.615385
# 21  Women's Athletic Footwear  Northeast  150.161616
# 22  Women's Athletic Footwear      South  222.215278
# 23  Women's Athletic Footwear  Southeast  271.039216
# 24  Women's Athletic Footwear       West  230.724138
# 25    Women's Street Footwear    Midwest  182.080128
# 26    Women's Street Footwear  Northeast  186.893939
# 27    Women's Street Footwear      South  285.614583
# 28    Women's Street Footwear  Southeast  321.019608
# 29    Women's Street Footwear       West  278.688725

# %%
plt.figure(figsize=(12,6))
plt.title("PRODUCT SALES")
plt.xlabel=("Product")
plt.ylabel=("Units Sold")
sns.barplot(x="Product",y="Units Sold",hue="Region",data=product_sales)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# 0           300000              0.5     In-store
# 1           150000              0.3     In-store
# 2           140000             0.35     In-store
# 3           133875             0.35     In-store
# 4           162000              0.3     In-store

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
product_perunit_sales=df.groupby("Product")[["Price per Unit","Total Sales"]].sum().reset_index()
product_perunit_sales
# Out:
#                      Product Price per Unit  Total Sales
# 0              Men's Apparel        80817.0  123728632.0
# 1    Men's Athletic Footwear        70485.0  153673680.0
# 2      Men's Street Footwear        71221.0  208826244.0
# 3            Women's Apparel        82974.0  179038860.0
# 4  Women's Athletic Footwear        66027.0  106631896.0
# 5    Women's Street Footwear        64726.0  128002813.0

# %%
plt.figure(figsize=(12,6))
plt.title=("Product with Per Unit and Total Sales")
plt.xlabel=("Price per Unit")
plt.ylabel=("Total Sales")
sns.barplot(x="Price per Unit",y="Total Sales",hue="Product",data=product_perunit_sales)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# 0           300000              0.5     In-store
# 1           150000              0.3     In-store
# 2           140000             0.35     In-store
# 3           133875             0.35     In-store
# 4           162000              0.3     In-store

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
product_salesmethod=df.groupby(["Product","Sales Method"])[["Units Sold"]].sum().reset_index()
product_salesmethod
# Out:
#                       Product Sales Method Units Sold
# 0               Men's Apparel     In-store      85375
# 1               Men's Apparel       Online     117766
# 2               Men's Apparel       Outlet     103542
# 3     Men's Athletic Footwear     In-store     117150
# 4     Men's Athletic Footwear       Online     163855
# 5     Men's Athletic Footwear       Outlet     154521
# 6       Men's Street Footwear     In-store     176030
# 7       Men's Street Footwear       Online     225121
# 8       Men's Street Footwear       Outlet     192169
# 9             Women's Apparel     In-store     120500
# 10            Women's Apparel       Online     163937
# 11            Women's Apparel       Outlet     149390
# 12  Women's Athletic Footwear     In-store      85450
# 13  Women's Athletic Footwear       Online     120755
# 14  Women's Athletic Footwear       Outlet     111031
# 15    Women's Street Footwear     In-store     105485
# 16    Women's Street Footwear       Online     147659
# 17    Women's Street Footwear       Outlet     139125

# %%
plt.figure(figsize=(12,6))
plt.title=("Product and Sales Method")
plt.xlabel=("Product")
plt.ylabel=("Units Sold")
sns.barplot(x="Product",y="Units Sold",hue="Sales Method",data=product_salesmethod)
plt.xticks(rotation=90);

# %%
px.bar(x="Product",y="Units Sold",color="Product",data_frame=product_salesmethod,barmode="group",title="Product and sales Method")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42888d05-2639-47b7-b308-d7c71bd90eee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42888d05-2639-47b7-b308-d7c71bd90eee")) {                    Plotly.newPlot(                        "42888d05-2639-47b7-b308-d7c71bd90eee",                        [{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men's Apparel","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Men's Apparel","offsetgroup":"Men's Apparel","orientation":"v","showlegend":true,"textposition":"auto","x":["Men's Apparel","Men's Apparel","Men's Apparel"],"xaxis":"x","y":[85375,117766,103542],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men's Athletic Footwear","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Men's Athletic Footwear","offsetgroup":"Men's Athletic Footwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Men's Athletic Footwear","Men's Athletic Footwear","Men's Athletic Footwear"],"xaxis":"x","y":[117150,163855,154521],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Men's Street Footwear","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Men's Street Footwear","offsetgroup":"Men's Street Footwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Men's Street Footwear","Men's Street Footwear","Men's Street Footwear"],"xaxis":"x","y":[176030,225121,192169],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women's Apparel","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Women's Apparel","offsetgroup":"Women's Apparel","orientation":"v","showlegend":true,"textposition":"auto","x":["Women's Apparel","Women's Apparel","Women's Apparel"],"xaxis":"x","y":[120500,163937,149390],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women's Athletic Footwear","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Women's Athletic Footwear","offsetgroup":"Women's Athletic Footwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Women's Athletic Footwear","Women's Athletic Footwear","Women's Athletic Footwear"],"xaxis":"x","y":[85450,120755,111031],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women's Street Footwear","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Women's Street Footwear","offsetgroup":"Women's Street Footwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Women's Street Footwear","Women's Street Footwear","Women's Street Footwear"],"xaxis":"x","y":[105485,147659,139125],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"o ...

# %%
px.line(x="Invoice Date",y="Units Sold",data_frame=df,title="Units sold By Invoice Method")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="935e972e-c39a-4464-8718-44bdfe670782" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("935e972e-c39a-4464-8718-44bdfe670782")) {                    Plotly.newPlot(                        "935e972e-c39a-4464-8718-44bdfe670782",                        [{"hovertemplate":"Invoice Date=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-31T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-24T00:00:00","2020-10-25T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-10-31T00:00:00","2020-11-01T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","20 ...

# %%
df.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# 0           300000              0.5     In-store
# 1           150000              0.3     In-store
# 2           140000             0.35     In-store
# 3           133875             0.35     In-store
# 4           162000              0.3     In-store

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
date_method_sold=df.groupby(["Invoice Date","Sales Method"])[["Units Sold"]].sum().reset_index()
date_method_sold
# Out:
#      Invoice Date Sales Method Units Sold
# 0      2020-01-01     In-store       1200
# 1      2020-01-01       Online        419
# 2      2020-01-01       Outlet        742
# 3      2020-01-02     In-store       1000
# 4      2020-01-02       Online        382
# ...           ...          ...        ...
# 1743   2021-12-29       Outlet        454
# 1744   2021-12-30       Online         89
# 1745   2021-12-30       Outlet        353
# 1746   2021-12-31       Online         83
# 1747   2021-12-31       Outlet        356
#
# [1748 rows x 3 columns]

# %%
px.bar(x="Invoice Date",y="Units Sold",color="Sales Method",data_frame=date_method_sold,barmode="group",title="Units sold with Sales Method and Invoice Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8724353d-0959-4537-b4c1-500057e07cbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8724353d-0959-4537-b4c1-500057e07cbf")) {                    Plotly.newPlot(                        "8724353d-0959-4537-b4c1-500057e07cbf",                        [{"alignmentgroup":"True","hovertemplate":"Sales Method=In-store\u003cbr\u003eInvoice Date=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"In-store","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"In-store","offsetgroup":"In-store","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06 ...

# %%
px.line(x="Invoice Date",y="Units Sold",data_frame=df,title="Units sold with Invoice Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5e10b618-3b7b-4899-b0c8-31453f318a06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e10b618-3b7b-4899-b0c8-31453f318a06")) {                    Plotly.newPlot(                        "5e10b618-3b7b-4899-b0c8-31453f318a06",                        [{"hovertemplate":"Invoice Date=%{x}\u003cbr\u003eUnits Sold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-31T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-08T00:00:00","2020-08-09T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-15T00:00:00","2020-08-16T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-22T00:00:00","2020-08-23T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-29T00:00:00","2020-08-30T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-24T00:00:00","2020-10-25T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-10-31T00:00:00","2020-11-01T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","20 ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
date_method_sold=df.groupby(["Invoice Date","Sales Method"])[["Units Sold"]].sum().reset_index()
date_method_sold
# Out:
#      Invoice Date Sales Method Units Sold
# 0      2020-01-01     In-store       1200
# 1      2020-01-01       Online        419
# 2      2020-01-01       Outlet        742
# 3      2020-01-02     In-store       1000
# 4      2020-01-02       Online        382
# ...           ...          ...        ...
# 1743   2021-12-29       Outlet        454
# 1744   2021-12-30       Online         89
# 1745   2021-12-30       Outlet        353
# 1746   2021-12-31       Online         83
# 1747   2021-12-31       Outlet        356
#
# [1748 rows x 3 columns]

# %%
in_store=date_method_sold[date_method_sold["Sales Method"]=="In-store"]
online=date_method_sold[date_method_sold["Sales Method"]=="Online"]
outlet=date_method_sold[date_method_sold["Sales Method"]=="Outlet"]

# %%
in_store
# Out:
#      Invoice Date Sales Method Units Sold
# 0      2020-01-01     In-store       1200
# 3      2020-01-02     In-store       1000
# 6      2020-01-03     In-store       1000
# 9      2020-01-04     In-store        850
# 12     2020-01-05     In-store        900
# ...           ...          ...        ...
# 1709   2021-12-15     In-store       3850
# 1712   2021-12-16     In-store       6600
# 1715   2021-12-17     In-store       2650
# 1722   2021-12-20     In-store       1550
# 1729   2021-12-23     In-store       7300
#
# [426 rows x 3 columns]

# %%
fig= make_subplots(rows=3,cols=1)
fig.append_trace(go.Line(x=in_store["Invoice Date"],y=in_store["Units Sold"]),row=1,col=1)
fig.append_trace(go.Line(x=online["Invoice Date"],y=online["Units Sold"]),row=2,col=1)
fig.append_trace(go.Line(x=outlet["Invoice Date"],y=outlet["Units Sold"]),row=3,col=1)
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="63875aa4-5a9c-4e3b-9c06-384c67a32cfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63875aa4-5a9c-4e3b-9c06-384c67a32cfb")) {                    Plotly.newPlot(                        "63875aa4-5a9c-4e3b-9c06-384c67a32cfb",                        [{"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00 ...

# %%
fig= make_subplots(x_title="Invoice Date",y_title="Units Sold",rows=3,cols=1)
fig.append_trace(go.Line(x=in_store["Invoice Date"],y=in_store["Units Sold"]),row=1,col=1)
fig.append_trace(go.Line(x=online["Invoice Date"],y=online["Units Sold"]),row=2,col=1)
fig.append_trace(go.Line(x=outlet["Invoice Date"],y=outlet["Units Sold"]),row=3,col=1)
fig.update_yaxes(range=[0,13000],row=3,col=1)
fig.update_layout(title_text= "Units Sold By Invoice Date")
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#
# /usr/local/lib/python3.12/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dbf5791a-4a1e-4c48-8381-f303c99629c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbf5791a-4a1e-4c48-8381-f303c99629c9")) {                    Plotly.newPlot(                        "dbf5791a-4a1e-4c48-8381-f303c99629c9",                        [{"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00 ...

# %%
df.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# 0           300000              0.5     In-store
# 1           150000              0.3     In-store
# 2           140000             0.35     In-store
# 3           133875             0.35     In-store
# 4           162000              0.3     In-store

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Product",y="Price per Unit",data=df)
plt.xlabel=("Product")
plt.ylabel=("Price per Unit")
plt.title=("Price per unit Product")

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Product",y="Price per Unit",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Price per Unit'>
